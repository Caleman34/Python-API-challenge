# %%
# dependencies
# %matplotlib inline
import os
import matplotlib.pyplot as plt
import numpy as np
import json
import requests
import pandas as pd
from scipy.stats import linregress

#import api key
from config import weather_api_key

#import citipy
from citipy import citipy

# %%
# Set up lists to hold response info
cities = []
lat_lngs = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Confirm sufficient city count
len(cities)
# Out:
# 604

# %%
units = 'imperial'
# build query url
query_url = f"http://api.openweathermap.org/data/2.5/weather?appid={weather_api_key}&units={units}&q="

# %%
# create arrays to be appended
city_data = []
temp = []
hum = []
cloud = []
wind = []
lat = []
lon = []

count = 0

for city in cities:
    json_response = requests.get(query_url + city).json()
    try:
        city_data.append(json_response['name'])
        temp.append(json_response['main']['temp_max'])
        hum.append(json_response['main']['humidity'])
        cloud.append(json_response['clouds']['all'])
        wind.append(json_response['wind']['speed'])
        lat.append(json_response['coord']['lat'])
        lon.append(json_response['coord']['lon'])
        count +=1
        print(f"{count}: Appending weather data for {city}")
                
    except KeyError:
        print(f"----Records not found for {city}----")

print("------------------------------")        
print("All cities have been processed")
# Out:
# 1: Appending weather data for bluff
# 2: Appending weather data for port lincoln
# 3: Appending weather data for vestmannaeyjar
# 4: Appending weather data for kysyl-syr
# 5: Appending weather data for busselton
# 6: Appending weather data for naco
# 7: Appending weather data for livingston
# 8: Appending weather data for ribeira grande
# 9: Appending weather data for punta arenas
# 10: Appending weather data for bredasdorp
# 11: Appending weather data for tonder
# 12: Appending weather data for dharchula
# 13: Appending weather data for new norfolk
# 14: Appending weather data for rikitea
# 15: Appending weather data for lawrenceburg
# 16: Appending weather data for hobart
# 17: Appending weather data for kapaa
# 18: Appending weather data for muriti
# 19: Appending weather data for sorsk
# 20: Appending weather data for cape town
# 21: Appending weather data for baijiantan
# 22: Appending weather data for saldanha
# 23: Appending weather data for nishihara
# 24: Appending weather data for hasaki
# 25: Appending weather data for ostersund
# 26: Appending weather data for hilo
# 27: Appending weather data for ushuaia
# 28: Appending weather data for emerald
# 29: Appending weather data for port alfred
# 30: Appending weather data for kavieng
# 31: Appending weather data for port macquarie
# 32: Appending weather data for cherskiy
# 33: Appending weather data for castro
# 34: Appending weather data for abha
# 35: Appending weather data for half moon bay
# 36: Appending weather data for beisfjord
# 37: Appending weather data for khash
# 38: Appending weather data for barrow
# 39: Appending weather data for vaini
# 40: Appending weather data for tasiilaq
# 41: Appending weather data for kantunilkin
# 42: Appending weather data for bethel
# 43: Appending weather data for nikolskoye
# ----Records not found for taolanaro----
# 44: Appending weather data for thompson
# 45: Appending weather data for skovorodino
# 46: Appending weather data for srednekolymsk
# 47: Appending weather data for lyngdal
# 48: Appending weather data for sitka
# 49: Appending weather data for parabel
# 50: Appending weather data for esperance
# 51: Appending weather data for upernavik
# 52: Appending weather data for pueblo nuevo
# 53: Appending weather data for yellowknife
# 54: Appending weather data for ravar
# 55: Appending weather data for tessalit
# 56: Appending weather data for namibe
# 57: Appending weather data for lorengau
# 58: Appending weather data for havelock
# 59: Appending weather data for norman wells
# 60: Appending weather data for pisco
# 61: Appending weather data for jamestown
# ----Records not found for mys shmidta----
# 62: Appending weather data for sidmouth
# 63: Appending weather data for chaoyang
# 64: Appending weather data for izhevskoye
# 65: Appending weather data for kahului
# 66: Appending weather data for chitipa
# 67: Appending weather data for hermanus
# 68: Appending weather data for hambantota
# ----Records not found for mizpe ramon----
# 69: Appending weather data for albany
# 70: Appending weather data for caninde de sao francisco
# 71: Appending weather data for allanridge
# 72: Appending weather data for airai
# 73: Appending weather data for makakilo city
# 74: Appending weather data for linkoping
# 75: Appending weather data for mahajanga
# 76: Appending weather data for albi
# 77: Appending weather data for buala
# 78: Appending weather data for fortuna
# 79: Appending weather data for mount isa
# 80: Appending weather data for butaritari
# ----Records not found for tumannyy----
# 81: Appending weather data for kavaratti
# 82: Appending weather data for portland
# 83: Appending weather data for shingu
# 84: Appending weather data for severo-kurilsk
# 85: Appending weather data for nanortalik
# 86: Appending weather data for lompoc
# 87: Appending weather data for ayr
# 88: Appending weather data for tuktoyaktuk
# 89: Appending weather data for henties bay
# 90: Appending weather data for el alto
# 91: Appending weather data for songjianghe
# ----Records not found for illoqqortoormiut----
# 92: Appending weather data for ostrovnoy
# 93: Appending weather data for atuona
# 94: Appending weather data for nhulunbuy
# 95: Appending weather data for caravelas
# 96: Appending weather data for rodeo
# 97: Appending weather data for mataura
# 98: Appending weather data for arraial do cabo
# 99: Appending weather data for marawi
# 100: Appending weather data for pinas
# 101: Appending weather data for ngunguru
# 102: Appending weather data for ciudad bolivar
# 103: Appending weather data for auki
# 104: Appending weather data for lebu
# 105: Appending weather data for vardo
# 106: Appending weather data for saint-philippe
# 107: Appending weather data for whitehorse
# 108: Appending weather data for le port
# 109: Appending weather data for carnarvon
# 110: Appending weather data for padang
# 111: Appending weather data for constitucion
# 112: Appending weather data for tungor
# 113: Appending weather data for floro
# 114: Appending weather data for wynyard
# 115: Appending weather data for narsaq
# 116: Appending weather data for dicabisagan
# 117: Appending weather data for kenai
# 118: Appending weather data for tubuala
# 119: Appending weather data for umm lajj
# 120: Appending weather data for kruisfontein
# 121: Appending weather data for saskylakh
# 122: Appending weather data for haimen
# 123: Appending weather data for hithadhoo
# 124: Appending weather data for novikovo
# 125: Appending weather data for chuy
# 126: Appending weather data for waterloo
# 127: Appending weather data for husavik
# 128: Appending weather data for san patricio
# 129: Appending weather data for guerrero negro
# 130: Appending weather data for provideniya
# 131: Appending weather data for katherine
# 132: Appending weather data for port moresby
# 133: Appending weather data for sawtell
# 134: Appending weather data for naze
# 135: Appending weather data for tiksi
# 136: Appending weather data for verkhniy baskunchak
# 137: Appending weather data for ahipara
# 138: Appending weather data for iqaluit
# 139: Appending weather data for kodiak
# 140: Appending weather data for mercedes
# ----Records not found for barentsburg----
# 141: Appending weather data for ambon
# 142: Appending weather data for nynashamn
# 143: Appending weather data for luderitz
# ----Records not found for paucartambo----
# ----Records not found for belushya guba----
# ----Records not found for sedelnikovo----
# 144: Appending weather data for chekhov
# 145: Appending weather data for loukhi
# 227: Appending weather data for clyde river
# 228: Appending weather data for ilulissat
# ----Records not found for umzimvubu----
# 229: Appending weather data for piracaia
# 230: Appending weather data for marang
# 231: Appending weather data for faanui
# 232: Appending weather data for geraldton
# ----Records not found for grand river south east----
# 233: Appending weather data for caraballeda
# 234: Appending weather data for cortona
# 235: Appending weather data for hirara
# 236: Appending weather data for ust-kut
# 237: Appending weather data for alofi
# 238: Appending weather data for general roca
# 239: Appending weather data for phan thiet
# 240: Appending weather data for kokopo
# 241: Appending weather data for saint anthony
# 242: Appending weather data for tocopilla
# 243: Appending weather data for bonfim
# 244: Appending weather data for durazno
# 245: Appending weather data for severo-yeniseyskiy
# 246: Appending weather data for xinyang
# 247: Appending weather data for sanghar
# 248: Appending weather data for puerto ayora
# 249: Appending weather data for ahuimanu
# 250: Appending weather data for penticton
# ----Records not found for bolungarvik----
# ----Records not found for macaboboni----
# ----Records not found for kerki----
# 251: Appending weather data for mecca
# 252: Appending weather data for nacala
# 253: Appending weather data for morelia
# 254: Appending weather data for ambilobe
# 255: Appending weather data for zabaykalsk
# 256: Appending weather data for bagotville
# 257: Appending weather data for puerto escondido
# 258: Appending weather data for hervey bay
# 259: Appending weather data for comodoro rivadavia
# 260: Appending weather data for longyearbyen
# 261: Appending weather data for macuelizo
# 262: Appending weather data for sao joao da barra
# 263: Appending weather data for saint-pierre
# 264: Appending weather data for codrington
# 265: Appending weather data for sarevere
# 266: Appending weather data for cidreira
# 267: Appending weather data for khatanga
# 268: Appending weather data for goderich
# 269: Appending weather data for innisfail
# 270: Appending weather data for lazaro cardenas
# 271: Appending weather data for bilma
# 272: Appending weather data for simojovel
# 273: Appending weather data for qaanaaq
# 274: Appending weather data for taloda
# 275: Appending weather data for luanda
# 276: Appending weather data for grootfontein
# 277: Appending weather data for solano
# 278: Appending weather data for akureyri
# 279: Appending weather data for uusikaupunki
# 280: Appending weather data for kodinar
# 281: Appending weather data for molina
# 282: Appending weather data for belmonte
# 283: Appending weather data for bousse
# 284: Appending weather data for bowen
# 285: Appending weather data for villa constitucion
# 286: Appending weather data for fort nelson
# 287: Appending weather data for nuevo progreso
# 288: Appending weather data for berlevag
# 289: Appending weather data for coos bay
# 290: Appending weather data for luziania
# 291: Appending weather data for sorland
# 292: Appending weather data for santa fe
# 293: Appending weather data for lasa
# 294: Appending weather data for zambezi
# 295: Appending weather data for silver city
# ----Records not found for palabuhanratu----
# 296: Appending weather data for honiara
# 297: Appending weather data for faya
# 298: Appending weather data for quatre cocos
# 299: Appending weather data for coquimbo
# ----Records not found for cheuskiny----
# 300: Appending weather data for bambanglipuro
# 301: Appending weather data for viedma
# 302: Appending weather data for boundiali
# 303: Appending weather data for gobabis
# 304: Appending weather data for komsomolskiy
# ----Records not found for saleaula----
# 305: Appending weather data for novooleksiyivka
# 306: Appending weather data for aswan
# 307: Appending weather data for scarborough
# 308: Appending weather data for sept-iles
# 309: Appending weather data for atbasar
# 482: Appending weather data for mehran
# 483: Appending weather data for yuancheng
# 484: Appending weather data for pingliang
# 485: Appending weather data for verkhnyaya inta
# 486: Appending weather data for inirida
# 487: Appending weather data for pochutla
# 488: Appending weather data for nizhniy kuranakh
# 489: Appending weather data for maneromango
# 490: Appending weather data for vostok
# 491: Appending weather data for pasighat
# ----Records not found for ondorhaan----
# 492: Appending weather data for aleksandrov gay
# 493: Appending weather data for winnemucca
# 494: Appending weather data for pokhara
# 495: Appending weather data for hastings
# 496: Appending weather data for stendal
# 497: Appending weather data for bathsheba
# 498: Appending weather data for victoria
# 499: Appending weather data for udachnyy
# 500: Appending weather data for sur
# 501: Appending weather data for miranda do corvo
# 502: Appending weather data for bintulu
# 503: Appending weather data for coahuayana
# 504: Appending weather data for khorinsk
# 505: Appending weather data for byron bay
# 506: Appending weather data for kemijarvi
# 507: Appending weather data for maine-soroa
# 508: Appending weather data for bima
# 509: Appending weather data for rocha
# 510: Appending weather data for evensk
# 511: Appending weather data for belton
# 512: Appending weather data for beidao
# 513: Appending weather data for songling
# 514: Appending weather data for zangakatun
# 515: Appending weather data for remiremont
# 516: Appending weather data for havre-saint-pierre
# 517: Appending weather data for bemidji
# 518: Appending weather data for roald
# 519: Appending weather data for impfondo
# 520: Appending weather data for samana
# 521: Appending weather data for adrar
# 522: Appending weather data for atherton
# 523: Appending weather data for lunino
# 524: Appending weather data for verkhnya syrovatka
# 525: Appending weather data for omsukchan
# 526: Appending weather data for mitsamiouli
# ----Records not found for karaul----
# 527: Appending weather data for quimperle
# 528: Appending weather data for egvekinot
# 529: Appending weather data for saurimo
# 530: Appending weather data for bullhead city
# 531: Appending weather data for hyeres
# 532: Appending weather data for vila velha
# 533: Appending weather data for odweyne
# 534: Appending weather data for huangchuan
# 535: Appending weather data for boa vista
# 536: Appending weather data for les escoumins
# 537: Appending weather data for kaka
# 538: Appending weather data for ziro
# 539: Appending weather data for sumkino
# 540: Appending weather data for miri
# 541: Appending weather data for ponta delgada
# 542: Appending weather data for manokwari
# 543: Appending weather data for kupang
# 544: Appending weather data for ondjiva
# 545: Appending weather data for paso de los toros
# 546: Appending weather data for kaseda
# 547: Appending weather data for andenes
# 548: Appending weather data for capim grosso
# 549: Appending weather data for nemuro
# 550: Appending weather data for maceio
# 551: Appending weather data for roma
# 552: Appending weather data for heihe
# 553: Appending weather data for urengoy
# 554: Appending weather data for coihaique
# 555: Appending weather data for nelson bay
# 556: Appending weather data for vicuna
# 557: Appending weather data for salinopolis
# 558: Appending weather data for podosinovets
# 559: Appending weather data for kautokeino
# ----Records not found for lolua----
# ------------------------------
# All cities have been processed

# %%
#import data into a weather data frame
weather_df = pd.DataFrame({"City Name": city_data,
                           "Max Temperature (F)": temp,
                           "Humidity (%)": hum,
                           "Cloudiness (%)": cloud,
                           "Wind Speed (mph)": wind,
                           "Latitude": lat,
                           "Longitude": lon})
weather_df.head()
# Out:
#         City Name  Max Temperature (F)  Humidity (%)  Cloudiness (%)  \
# 0           Bluff                49.03            86              40
# 1    Port Lincoln                61.81            61              89
# 2  Vestmannaeyjar                43.79            75              40
# 3       Kysyl-Syr                47.82            36              82
# 4       Busselton                57.09            88              93
#
#    Wind Speed (mph)  Latitude  Longitude
# 0              9.66  -46.6000   168.3333
# 1              7.99  -34.7333   135.8667
# 2             16.11   63.4427   -20.2734
# 3              6.80   63.8986   122.7617
# 4             13.09  -33.6500   115.3333

# %%
# create file for city weather data in csv format
weather_df.to_csv("Analysis/WeatherAPI/weather_df.csv", index=False, header=True)

# %%
# check data types
weather_df.dtypes
# Out:
# City Name               object
# Max Temperature (F)    float64
# Humidity (%)             int64
# Cloudiness (%)           int64
# Wind Speed (mph)       float64
# Latitude               float64
# Longitude              float64
# dtype: object

# %%
# describe data
weather_df.describe()
# Out:
#        Max Temperature (F)  Humidity (%)  Cloudiness (%)  Wind Speed (mph)  \
# count           559.000000    559.000000      559.000000        559.000000
# mean             65.892218     66.345259       58.069767          8.633739
# std              18.380202     24.122610       36.775067          6.104733
# min              10.630000      5.000000        0.000000          0.000000
# 25%              53.130000     50.000000       20.000000          4.040000
# 50%              67.030000     73.000000       70.000000          7.020000
# 75%              79.070000     86.000000       92.000000         11.700000
# max             111.110000    100.000000      100.000000         35.680000
#
#          Latitude   Longitude
# count  559.000000  559.000000
# mean    18.943467   18.002352
# std     34.365785   91.147170
# min    -54.800000 -179.166700
# 25%    -10.117400  -61.000150
# 50%     21.461200   18.116700
# 75%     50.156850  101.309900
# max     78.218600  179.316700

# %%
#create scatter pluts comparing temp and lat
plt.scatter(weather_df["Max Temperature (F)"], weather_df["Latitude"])
plt.title("Max Temperature (F) vs. Latitude")
plt.xlabel("Max Temperature (F)")
plt.ylabel("Latitude")
plt.grid(True)

# save figure
plt.savefig("Analysis/WeatherAPI/tempvslat.png")

plt.show()
print("According to the scatterplot, cities that are closer to the equator,")
print("have a higher temperature than cities that are further away from the equator.")
# Out:
# According to the scatterplot, cities that are closer to the equator,
# have a higher temperature than cities that are further away from the equator.

# %%
#create scatter pluts comparing hum vs lat
plt.scatter(weather_df["Humidity (%)"], weather_df["Latitude"])
plt.title("Humidity (%) vs. Latitude")
plt.xlabel("Humidity (%)")
plt.ylabel("Latitude")
plt.grid(True)

# save figure
plt.savefig("Analysis/WeatherAPI/humvslat.png")

plt.show()
print("According to the scatterplot, there humidity ranges widely depending on your location.")
print("There is no clear direct relation shown.")
print("There is a stronger cluster of citied with high humidity overall, however they are spread evenly between distances from the equator.")
print("There are fewer cities with humidity below 50%, and they tend to be in the northern hemisphere and are at or below 40 degrees lat.")
# Out:
# According to the scatterplot, there humidity ranges widely depending on your location.
# There is no clear direct relation shown.
# There is a stronger cluster of citied with high humidity overall, however they are spread evenly between distances from the equator.
# There are fewer cities with humidity below 50%, and they tend to be in the northern hemisphere and are at or below 40 degrees lat.

# %%
#create scatter pluts comparing cloud vs lat
plt.scatter(weather_df["Cloudiness (%)"], weather_df["Latitude"])
plt.title("Cloudiness (%) vs. Latitude")
plt.xlabel("Cloudiness (%)")
plt.ylabel("Latitude")
plt.grid(True)

# save figure
plt.savefig("Analysis/WeatherAPI/cloudvslat.png")

plt.show()
print("According to the scatterplot, there is no apparent correlation betwen latitude and coudiness.")
print("The distribution is even across all lattitues")
# Out:
# According to the scatterplot, there is no apparent correlation betwen latitude and coudiness.
# The distribution is even across all lattitues

# %%
#create scatter pluts comparing wind speed vs lat
plt.scatter(weather_df["Wind Speed (mph)"], weather_df["Latitude"])
plt.title("Wind Speed (mph) vs. Latitude")
plt.xlabel("Wind Speed (mph)")
plt.ylabel("Latitude")
plt.grid(True)

# save figure
plt.savefig("Analysis/WeatherAPI/windvslat.png")

plt.show()
print("According to the scatterplot, wind speed overall is does not exceed 15 mph for the majority of the cities.")
print("There appears to be a higher cluster of cities in the northeren hemisphere that have wind speeds")
print("between 0 mph and 10 mph when compared to the southern hemisphere as a whole")
# Out:
# According to the scatterplot, wind speed overall is does not exceed 15 mph for the majority of the cities.
# There appears to be a higher cluster of cities in the northeren hemisphere that have wind speeds
# between 0 mph and 10 mph when compared to the southern hemisphere as a whole

# %%
# create new df to spilt the n and s hemispheres
northern_df = weather_df.loc[weather_df["Latitude"] >= 0, :]
southern_df = weather_df.loc[weather_df["Latitude"] < 0, :]
northern_df.head()
# Out:
#         City Name  Max Temperature (F)  Humidity (%)  Cloudiness (%)  \
# 2  Vestmannaeyjar                43.79            75              40
# 3       Kysyl-Syr                47.82            36              82
# 5            Naco                62.69            52               0
# 6      Livingston                52.68            57              40
# 7  Ribeira Grande                63.00            55              20
#
#    Wind Speed (mph)  Latitude  Longitude
# 2             16.11   63.4427   -20.2734
# 3              6.80   63.8986   122.7617
# 5              5.59   31.3347  -109.9483
# 6              7.74   55.9029    -3.5226
# 7             13.80   38.5167   -28.7000

# %%
southern_df.head()
# Out:
#       City Name  Max Temperature (F)  Humidity (%)  Cloudiness (%)  \
# 0         Bluff                49.03            86              40
# 1  Port Lincoln                61.81            61              89
# 4     Busselton                57.09            88              93
# 8  Punta Arenas                44.71            87              75
# 9    Bredasdorp                61.92            52               3
#
#    Wind Speed (mph)  Latitude  Longitude
# 0              9.66  -46.6000   168.3333
# 1              7.99  -34.7333   135.8667
# 4             13.09  -33.6500   115.3333
# 8              2.91  -53.1500   -70.9167
# 9              6.46  -34.5322    20.0403

# %%
# nh- temp v lat
x_values = northern_df["Latitude"]
y_values = northern_df["Max Temperature (F)"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.title("Northern Hemisphere Latitude vs. Max Temperature (F)")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")

# save figure
plt.savefig("Analysis/WeatherAPI/nh_temp_v_lat.png")

plt.show()

print("There is a strong correlation between temperature and latitude.  As latitude increases, temperature decreases")
print("This means there is a higher temperature for cities closer to the equator in the northern hemisphere")
# Out:
# There is a strong correlation between temperature and latitude.  As latitude increases, temperature decreases
# This means there is a higher temperature for cities closer to the equator in the northern hemisphere

# %%
# sh- temp v lat
x_values = southern_df["Latitude"]
y_values = southern_df["Max Temperature (F)"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.title("Southern Hemisphere Latitude vs. Max Temperature (F)")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")

# save figure
plt.savefig("Analysis/WeatherAPI/sh_temp_v_lat.png")

plt.show()

print("There is a strong correlation between temperature and latitude.  As latitude decreases, temperature decreases as well")
print("This means there is a lowr temperature for cities further away from to the equator in the southern hemisphere.")
# Out:
# There is a strong correlation between temperature and latitude.  As latitude decreases, temperature decreases as well
# This means there is a lowr temperature for cities further away from to the equator in the southern hemisphere.

# %%
# nh- hum v lat
x_values = northern_df["Latitude"]
y_values = northern_df["Humidity (%)"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.title("Northern Hemisphere Latitude vs. Humidity (%)")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")

# save figure
plt.savefig("Analysis/WeatherAPI/nh_hum_v_lat.png")

plt.show()

print("There is a weak correlation between latitude and humidity.  However, cities closer to the equator are more likely to have high humidity.")
# Out:
# There is a weak correlation between latitude and humidity.  However, cities closer to the equator are more likely to have high humidity.

# %%
# sh- hum v lat
x_values = southern_df["Latitude"]
y_values = southern_df["Humidity (%)"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.title("Southern Hemisphere Latitude vs. Humidity (%)")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")

# save figure
plt.savefig("Analysis/WeatherAPI/sh_hum_v_lat.png")

plt.show()

print("There is a very weak if any correlation between latitude and humidity. However cities that are cloder to the equator are more likely to have high humidity than low.")
print("Cities that are between -30 and -20 latitudes are evenly spread between low and high humidity")
# Out:
# There is a very weak if any correlation between latitude and humidity. However cities that are cloder to the equator are more likely to have high humidity than low.
# Cities that are between -30 and -20 latitudes are evenly spread between low and high humidity

# %%
# nh- hum v lat
x_values = northern_df["Latitude"]
y_values = northern_df["Cloudiness (%)"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.title("Northern Hemisphere Latitude vs. Cloudiness (%)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")

# save figure
plt.savefig("Analysis/WeatherAPI/nh_cloud_v_lat.png")

plt.show()

print("There is no correlation between cloudiness and latitude in the northern hemisphere")
# Out:
# There is no correlation between cloudiness and latitude in the northern hemisphere

# %%
# sh- hum v lat
x_values = southern_df["Latitude"]
y_values = southern_df["Cloudiness (%)"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.title("Southern Hemisphere Latitude vs. Cloudiness (%)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")

# save figure
plt.savefig("Analysis/WeatherAPI/sh_cloud_v_lat.png")

plt.show()

print("There is no correlation between cloudiness and latitude in the southern hemisphere")
# Out:
# There is no correlation between cloudiness and latitude in the southern hemisphere

# %%
# nh- wind v lat
x_values = northern_df["Latitude"]
y_values = northern_df["Wind Speed (mph)"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.title("Northern Hemisphere Latitude vs. Wind Speed (mph))")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")

# save figure
plt.savefig("Analysis/WeatherAPI/nh_wind_v_lat.png")

plt.show()

print("Overall city wind speeds are below 15 mph whether the city is close to the equator or further away.")
print("There is no correlation between wind speed and latitude as the data is evenly distributed in the northern hemisphere.")
# Out:
# Overall city wind speeds are below 15 mph whether the city is close to the equator or further away.
# There is no correlation between wind speed and latitude as the data is evenly distributed in the northern hemisphere.

# %%
# sh- wind v lat
x_values = southern_df["Latitude"]
y_values = southern_df["Wind Speed (mph)"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.title("Southern Hemisphere Latitude vs. Wind Speed (mph))")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")

# save figure
plt.savefig("Analysis/WeatherAPI/sh_wind_v_lat.png")

plt.show()

print("Overall city wind speeds are below 15 mph whether the city is close to the equator or further away.")
print("There is no correlation between wind speed and latitude as the data is evenly distributed in the southern hemisphere.")
# Out:
# Overall city wind speeds are below 15 mph whether the city is close to the equator or further away.
# There is no correlation between wind speed and latitude as the data is evenly distributed in the southern hemisphere.
